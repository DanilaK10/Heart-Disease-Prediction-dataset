# %% [markdown]
# <a href="https://colab.research.google.com/github/DanilaK10/Heart-Disease-Prediction-dataset/blob/main/lab4%204_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 4-9. Correlations
#
# heat map of correlations between features

# %%
def correlation_heatmap(data):
    """
    Correlation Heat Map of the features.
    """
    plt.figure(figsize=(11, 7))
    sns.heatmap(data.corr(), annot=True, linewidth=0.2,
                fmt='.2f', cmap='RdGy_r')
    plt.title('Correlations between Features', fontsize=15)
    plt.show()
    """
    - creates a figure
    - figsize is a tuple of the width and height of the figure in inches
    - used to plot rectangular data in the form of a color-coded matrix
     """

correlation_heatmap(df);

# %% [markdown]
# Observations
#
# Top correlated variables for Condition following:
# - Chest_pain_type: 0.43
# - Max_heart_rate: 0.42
# - ST_slope: 0.35
#
# ![image.png](data:image/png;base64,...)
