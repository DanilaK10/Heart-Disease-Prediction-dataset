# %% [markdown]
# <a href="https://colab.research.google.com/github/DanilaK10/Heart-Disease-Prediction-dataset/blob/main/Final_report/KNN_%2B_RF_%2B_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the data

# %% [markdown]
# Down below it imports all the libaries needed for the tasks and it also retrieves the dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')
import plotly.graph_objs as go
import plotly.offline as py
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/DanilaK10/Heart-Disease-Prediction-dataset/main/Heart%20Disease%20Dataset.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # 3.2 Renaming Columns

# %% [markdown]
# Renames the columns in the dataset - it is required later on with some of the tasks.

# %%
#renaming columns - Kaggle - 3.2
df.columns = ["Age", "Sex", "Chest_pain_type", "Resting_bp", "Cholesterol", "Fasting_bs", "Resting_ecg", "Max_heart_rate", "Exercise_induced_angina", "ST_depression", "ST_slope", "Num_major_vessels", "Thallium_test", "Condition"]
df
# Out:
#      Age  Sex  Chest_pain_type  Resting_bp  Cholesterol  Fasting_bs  \
# 0     63    1                3         145          233           1
# 1     37    1                2         130          250           0
# 2     41    0                1         130          204           0
# 3     56    1                1         120          236           0
# 4     57    0                0         120          354           0
# ..   ...  ...              ...         ...          ...         ...
# 298   57    0                0         140          241           0
# 299   45    1                3         110          264           0
# 300   68    1                0         144          193           1
# 301   57    1                0         130          131           0
# 302   57    0                1         130          236           0
#
#      Resting_ecg  Max_heart_rate  Exercise_induced_angina  ST_depression  \
# 0              0             150                        0            2.3
# 1              1             187                        0            3.5
# 2              0             172                        0            1.4
# 3              1             178                        0            0.8
# 4              1             163                        1            0.6
# ..           ...             ...                      ...            ...
# 298            1             123                        1            0.2
# 299            1             132                        0            1.2
# 300            1             141                        0            3.4
# 301            1             115                        1            1.2
# 302            0             174                        0            0.0
#
#      ST_slope  Num_major_vessels  Thallium_test  Condition
# 0           0                  0              1          1
# 1           0                  0              2          1
# 2           2                  0              2          1
# 3           2                  0              2          1
# 4           2                  0              2          1
# ..        ...                ...            ...        ...
# 298         1                  0              3          0
# 299         1                  0              3          0
# 300         1                  2              3          0
# 301         1                  1              3          0
# 302         1                  1              2          0
#
# [303 rows x 14 columns]

# %% [markdown]
# # Splitting the data

# %% [markdown]
# x is for all the values from the dataset except whether the patient has Heart disease or not. This data will then be used to train the model with the y which contains the corresponding values for whether that particular patient has heart disease or not.
#
# >
#
# test_size represents the amount of data left over from the dataset for x_test and y_test (0.2 means 20%) and random_state randomizes the order of the data from the dataset.

# %%
y = df["Condition"] # - y is the condition values from the dataset
x = df.drop("Condition", axis = 1) # - x is the dataset with condition removed
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=23)
x_test
# Out:
#      Age  Sex  Chest_pain_type  Resting_bp  Cholesterol  Fasting_bs  \
# 231   57    1                0         165          289           1
# 46    44    1                2         140          235           0
# 2     41    0                1         130          204           0
# 272   67    1                0         120          237           0
# 243   57    1                0         152          274           0
# ..   ...  ...              ...         ...          ...         ...
# 59    57    0                0         128          303           0
# 19    69    0                3         140          239           0
# 296   63    0                0         124          197           0
# 64    58    1                2         140          211           1
# 45    52    1                1         120          325           0
#
#      Resting_ecg  Max_heart_rate  Exercise_induced_angina  ST_depression  \
# 231            0             124                        0            1.0
# 46             0             180                        0            0.0
# 2              0             172                        0            1.4
# 272            1              71                        0            1.0
# 243            1              88                        1            1.2
# ..           ...             ...                      ...            ...
# 59             0             159                        0            0.0
# 19             1             151                        0            1.8
# 296            1             136                        1            0.0
# 64             0             165                        0            0.0
# 45             1             172                        0            0.2
#
#      ST_slope  Num_major_vessels  Thallium_test
# 231         1                  3              3
# 46          2                  0              2
# 2           2                  0              2
# 272         1                  0              2
# 243         1                  1              3
# ..        ...                ...            ...
# 59          2                  1              2
# 19          2                  2              2
# 296         1                  0              2
# 64          2                  0              2
# 45          2                  0              2
#
# [61 rows x 13 columns]

# %% [markdown]
# # Normalization of test + train data
#
#
# >
#
# https://stats.stackexchange.com/questions/287425/why-do-you-need-to-scale-data-in-knn

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
normalized_x_train = scalar.fit_transform(x_train)
normalized_x_test = scalar.fit_transform(x_test)

# %% [markdown]
# # KNeighbors Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(normalized_x_train,y_train)
y_pred_KNN = KNN.predict(normalized_x_test)

# %% [markdown]
# ## GridSearch to find best paramaters for Kneighbor Classifier
# n_neighbor = 10
# >
# p = 1
# >
# weights = distance
# >
# algorithm + leaf_size dont seem to change accuracy

# %%
from sklearn.model_selection import GridSearchCV
k_range = list(range(9,15))
l_size = list(range(1,5))
paramater_grid = dict(n_neighbors = k_range, weights = ["distance"],algorithm = ["ball_tree"], leaf_size = l_size,p = [1])
grid = GridSearchCV(KNN, paramater_grid, cv=5, scoring = "accuracy")
grid.fit(normalized_x_train,y_train)
pd.DataFrame(grid.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#     mean_test_score  std_test_score  \
# 0          0.834694        0.047241
# 1          0.834779        0.056814
# 2          0.830527        0.060550
# 3          0.834609        0.057304
# 4          0.830442        0.036174
# 5          0.830442        0.040345
# 6          0.834694        0.047241
# 7          0.834779        0.056814
# 8          0.830527        0.060550
# 9          0.834609        0.057304
# 10         0.830442        0.036174
# 11         0.830442        0.040345
# 12         0.834694        0.047241
# 13         0.834779        0.056814
# 14         0.830527        0.060550
# 15         0.834609        0.057304
# 16         0.830442        0.036174
# 17         0.830442        0.040345
# 18         0.834694        0.047241
# 19         0.834779        0.056814
# 20         0.830527        0.060550
# 21         0.834609        0.057304
# 22         0.830442        0.036174
# 23         0.830442        0.040345
#
#                                                params
# 0   {'algorithm': 'ball_tree', 'leaf_size': 1, 'n_...
# 1   {'algorithm': 'ball_tree', 'leaf_size': 1, 'n_...
# 2   {'algorithm': 'ball_tree', 'leaf_size': 1, 'n_...
# 3   {'algorithm': 'ball_tree', 'leaf_size': 1, 'n_...
# 4   {'algorithm': 'ball_tree', 'leaf_size': 1, 'n_...
# 5   {'algorithm': 'ball_tree', 'leaf_size': 1, 'n_...
# 6   {'algorithm': 'ball_tree', 'leaf_size': 2, 'n_...
# 7   {'algorithm': 'ball_tree', 'leaf_size': 2, 'n_...
# 8   {'algorithm': 'ball_tree', 'leaf_size': 2, 'n_...
# 9   {'algorithm': 'ball_tree', 'leaf_size': 2, 'n_...
# 10  {'algorithm': 'ball_tree', 'leaf_size': 2, 'n_...
# 11  {'algorithm': 'ball_tree', 'leaf_size': 2, 'n_...
# 12  {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...
# 13  {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...
# 14  {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...
# 15  {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...
# 16  {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...
# 17  {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...
# 18  {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...
# 19  {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...
# 20  {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...
# 21  {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...
# 22  {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...
# 23  {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...

# %%
print(grid.best_score_)
print(grid.best_params_)
#print(normalized_train_x)
# Out:
# 0.8347789115646259
# {'algorithm': 'ball_tree', 'leaf_size': 1, 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfm = RandomForestClassifier()
rfm.fit(normalized_x_train,y_train)
y_pred_rfm = rfm.predict(normalized_x_test)

# %% [markdown]
# ## Random Forest GridSearch

# %%
from sklearn.model_selection import GridSearchCV
n_range = list(range(22,23)) #35
l_size = list(range(14,15))
ran_range = list(range(103,104))
paramater_grid = dict(n_estimators = n_range, min_samples_leaf = l_size, max_features = ["sqrt"], random_state = ran_range)
grid = GridSearchCV(rfm, paramater_grid, cv=5, scoring = "accuracy")
grid.fit(normalized_x_train,y_train)
pd.DataFrame(grid.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#    mean_test_score  std_test_score  \
# 0         0.863776        0.020106
#
#                                               params
# 0  {'max_features': 'sqrt', 'min_samples_leaf': 1...

# %% [markdown]
# #Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter = 1000)
lr.fit(normalized_x_train, y_train)
y_pred=lr.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning:
#
# X has feature names, but LogisticRegression was fitted without feature names

# %% [markdown]
# ## Gridsearch LR

# %%
from sklearn.model_selection import GridSearchCV
#n_range = list(range(22,23)) #35
#l_size = list(range(14,15))
#ran_range = list(range(103,104))
paramater_grid = dict(penalty = ["l2"], fit_intercept = [True], class_weight = [None],solver = ["lbfgs"],warm_start = [True])
grid = GridSearchCV(lr, paramater_grid, cv=5, scoring = "accuracy")
grid.fit(normalized_x_train,y_train)
pd.DataFrame(grid.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#    mean_test_score  std_test_score  \
# 0         0.847109        0.038398
#
#                                               params
# 0  {'class_weight': None, 'fit_intercept': True, ...
